# %% [markdown]
# # Downloading Raw Data From From IB
# ## Objective
# Download History (only last 2 years for each symbol)
# Download Daily (Hourly Updates
#
# Download all required maturities for each symbol Store all contracts for each symbol in one table Download pre-requisites
# Control data:¶
#
# Market data for download contracts
# MySQL pre-requisites
#
# imports:
# ib_sync (

# %%
import pandas as pd
import numpy as np
from ib_insync import *

ib = IB()
ib.connect('127.0.0.1', 7497, clientId=2)
# Out:
# <IB connected to 127.0.0.1:7497 clientId=2>

# %%
# Get marketdata from database...
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://root:kobi5555@0.0.0.0/proddb')

# %%
def get_month_symbols(keys):
    return [{
        '01': 'F',
        '02': 'G',
        '03': 'H',
        '04': 'J',
        '05': 'K',
        '06': 'M',
        '07': 'N',
        '08': 'Q',
        '09': 'U',
        '10': 'V',
        '11': 'X',
        '12': 'Z'
    }[key] for key in keys ]

# %%
marketdata_df = pd.read_sql_table(table_name="marketdata", con=engine)
marketdata_df.set_index('CARVER', inplace=True)
marketdata_df.tail()
# Out:
#        QUANDL    IB SECTYPE CURRENCY Q_EXCHANGE IB_EXCHANGE  MULTIPLIER
# CARVER
# US10       TY    ZN     FUT      USD        CME       ECBOT           0
# US20       US    ZB     FUT      USD        CME       ECBOT           0
# V2X       FVS  V2TX     FUT      EUR      EUREX         DTB           0
# VIX        VX   VIX     FUT      USD       CBOE         CFE           0
# WHEAT       W    ZW     FUT      USD        CME       ECBOT           0

# %%
marketdata_df.loc['AEX']
# Out:
# QUANDL           FTI
# IB               EOE
# SECTYPE          FUT
# CURRENCY         EUR
# Q_EXCHANGE     LIFFE
# IB_EXCHANGE      FTA
# MULTIPLIER       200
# Name: AEX, dtype: object

# %%
roll_schedule = pd.read_sql_table(table_name="roll_schedule", con=engine)
aex_schedule = roll_schedule[roll_schedule.CARVER == 'AEX']
aex_schedule.head()
# Out:
#   CARVER   DATETIME CARRY_CONTRACT PRICE_CONTRACT
# 0    AEX 2013-07-26         201311         201310
# 1    AEX 2013-10-18         201312         201311
# 2    AEX 2013-11-15         201401         201312
# 3    AEX 2013-12-18         201402         201401
# 4    AEX 2014-01-17         201403         201402

# %%
aex = Future('EOE', exchange='FTA', multiplier=200, includeExpired=True)
cds = ib.reqContractDetails(aex)
len(cds)
# Out:
# 30

# %%
contracts = [cd.summary for cd in cds]
df_aex = util.df(contracts)
df_aex
# Out:
#    secType      conId symbol lastTradeDateOrContractMonth  strike right  \
# 0      FUT  187676416    EOE                     20160318     0.0
# 1      FUT  198024163    EOE                     20160617     0.0
# 2      FUT  207598895    EOE                     20160916     0.0
# 3      FUT  216186092    EOE                     20161216     0.0
# 4      FUT  219762210    EOE                     20160415     0.0
# 5      FUT  223545271    EOE                     20160520     0.0
# 6      FUT  226638493    EOE                     20170317     0.0
# 7      FUT  230411376    EOE                     20160715     0.0
# 8      FUT  234643411    EOE                     20160819     0.0
# 9      FUT  237778126    EOE                     20170616     0.0
# 10     FUT  241406624    EOE                     20161021     0.0
# 11     FUT  244930738    EOE                     20161118     0.0
# 12     FUT  248650400    EOE                     20170915     0.0
# ...

# %% [markdown]
# ## History
# Cycle through all markets and download all data that is available
#
# contract_4391 = Contract(conId=4391)
#
# ib.qualifyContracts(contract_4391)
#
# assert contract_4391 == amd

# %%
## Select all contracts that are in schedule.

# %%
get_local_symbol('EOE', '201802')
# Out:
# 'EOEG8'

# %%
df_aex['localSymbolMonth'] = df_aex['multiplier'][:2]
df_aex.head()
# Out:
#   secType      conId symbol lastTradeDateOrContractMonth  strike right  \
# 0     FUT  187676416    EOE                     20160318     0.0
# 1     FUT  198024163    EOE                     20160617     0.0
# 2     FUT  207598895    EOE                     20160916     0.0
# 3     FUT  216186092    EOE                     20161216     0.0
# 4     FUT  219762210    EOE                     20160415     0.0
#
#   multiplier exchange primaryExchange currency localSymbol tradingClass  \
# 0        200      FTA                      EUR       FTIH6          FTI
# 1        200      FTA                      EUR       FTIM6          FTI
# 2        200      FTA                      EUR       FTIU6          FTI
# 3        200      FTA                      EUR       FTIZ6          FTI
# 4        200      FTA                      EUR       FTIJ6          FTI
#
#   includeExpired secIdType secId comboLegsDescrip comboLegs underComp  \
# ...

# %%
df_aex['localSymbolMonth'] = df_aex.apply(lambda df_aex: df_aex['localSymbol'][3:4], axis=1)

# %%
df_aex.head()
# Out:
#   secType      conId symbol lastTradeDateOrContractMonth  strike right  \
# 0     FUT  187676416    EOE                     20160318     0.0
# 1     FUT  198024163    EOE                     20160617     0.0
# 2     FUT  207598895    EOE                     20160916     0.0
# 3     FUT  216186092    EOE                     20161216     0.0
# 4     FUT  219762210    EOE                     20160415     0.0
#
#   multiplier exchange primaryExchange currency localSymbol tradingClass  \
# 0        200      FTA                      EUR       FTIH6          FTI
# 1        200      FTA                      EUR       FTIM6          FTI
# 2        200      FTA                      EUR       FTIU6          FTI
# 3        200      FTA                      EUR       FTIZ6          FTI
# 4        200      FTA                      EUR       FTIJ6          FTI
#
#   includeExpired secIdType secId comboLegsDescrip comboLegs underComp  \
# ...

# %%
unique_set = set(pd.concat([aex_schedule.apply(lambda aex_schedule: aex_schedule['CARRY_CONTRACT'][4:], axis=1),
                            aex_schedule.apply(lambda aex_schedule: aex_schedule['PRICE_CONTRACT'][4:], axis=1)]))
    
unique_set
# Out:
# {'01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12'}

# %%
df_contracts = df_aex[df_aex['localSymbolMonth'].isin(get_month_symbols(unique_set))]

# %%
pd.to_datetime(df_contracts.iloc[0]['lastTradeDateOrContractMonth'][:8])
# Out:
# Timestamp('2016-03-18 00:00:00')

# %%
df_contracts
# Out:
#    secType      conId symbol lastTradeDateOrContractMonth  strike right  \
# 0      FUT  187676416    EOE                     20160318     0.0
# 1      FUT  198024163    EOE                     20160617     0.0
# 2      FUT  207598895    EOE                     20160916     0.0
# 3      FUT  216186092    EOE                     20161216     0.0
# 4      FUT  219762210    EOE                     20160415     0.0
# 5      FUT  223545271    EOE                     20160520     0.0
# 6      FUT  226638493    EOE                     20170317     0.0
# 7      FUT  230411376    EOE                     20160715     0.0
# 8      FUT  234643411    EOE                     20160819     0.0
# 9      FUT  237778126    EOE                     20170616     0.0
# 10     FUT  241406624    EOE                     20161021     0.0
# 11     FUT  244930738    EOE                     20161118     0.0
# 12     FUT  248650400    EOE                     20170915     0.0
# ...

# %%
import datetime
datetime.datetime.today() - datetime.timedelta(2)
# Out:
# datetime.datetime(2018, 3, 4, 0, 12, 38, 80428)

# %%
for row in df_contracts.itertuples():
    contract = Contract(conId=row.conId, includeExpired=True)
    ib.qualifyContracts(contract)
    last_trade_date = pd.to_datetime(df_contracts.loc[row.Index]['lastTradeDateOrContractMonth'][:8])
    last_trade_date_str = last_trade_date.strftime("%Y%m%d %H:%M:%S")
    head_date = ib.reqHeadTimeStamp(contract, whatToShow='TRADES', useRTH=True)
    head_date = head_date + datetime.timedelta(365)
    head_date_str = head_date.strftime("%Y%m%d %H:%M:%S")
    end_date = row.lastTradeDateOrContractMonth
    end_date = end_date + " 00:00:00"
    print('head_date_str: ', head_date_str, "last_trade_date_str: ", last_trade_date_str)  
    bars = ib.reqHistoricalData(
        contract,
        last_trade_date_str,
        #'20180318 00:00:00',
        #end_date,
        durationStr='365 D',
        barSizeSetting='1 day',
        whatToShow='TRADES',
        useRTH=True,
        formatDate=1)
    df = util.df(bars)
    df.tail()
# Out:
# [Contract(secType='FUT', conId=187676416, symbol='EOE', lastTradeDateOrContractMonth='20160318', multiplier='200', exchange='FTA', currency='EUR', localSymbol='FTIH6', tradingClass='FTI')]
# head_date_str:  20160414 06:00:00 last_trade_date_str:  20160318 00:00:00
#            date    open    high     low   close  volume  barCount   average
# 173  2016-03-11  436.25  443.60  435.60  441.80   33389     21476  440.4750
# 174  2016-03-14  443.15  447.10  441.85  444.05   28996     18579  444.5850
# 175  2016-03-15  442.90  443.25  439.50  442.00   22234     14352  441.3525
# 176  2016-03-16  443.45  445.50  440.50  443.85   23877     15774  443.5150
# 177  2016-03-17  446.20  447.75  435.55  444.10   37117     24458  440.8900
# [Contract(secType='FUT', conId=198024163, symbol='EOE', lastTradeDateOrContractMonth='20160617', multiplier='200', exchange='FTA', currency='EUR', localSymbol='FTIM6', tradingClass='FTI')]
# ...

# %%
ib.reqHistoricalData

# %%
endDate = ib.reqHeadTimeStamp(contract_a, whatToShow='TRADES', useRTH=True)
endDate
# Out:
# datetime.datetime(2016, 7, 25, 6, 0)

# %%
endDate.strftime("%Y%m%d")
# Out:
# '20160725'

# %%
bars = ib.reqHistoricalData(
        contract_247950613,
        '', 
        durationStr='60 D',
        barSizeSetting='1 day',
        whatToShow='TRADES',
        useRTH=True,
        formatDate=1)

# %%
bars
# Out:
# [BarData(date=datetime.date(2017, 12, 6), open=2625.75, high=2634.5, low=2624.0, close=2629.25, volume=800807, barCount=84684, average=2629.7125),
#  BarData(date=datetime.date(2017, 12, 7), open=2627.75, high=2641.25, low=2626.25, close=2639.5, volume=680125, barCount=73807, average=2635.3125),
#  BarData(date=datetime.date(2017, 12, 8), open=2646.75, high=2652.5, low=2644.0, close=2651.0, volume=361343, barCount=40959, average=2648.725),
#  BarData(date=datetime.date(2017, 12, 11), open=2652.5, high=2664.75, low=2651.75, close=2661.625, volume=240531, barCount=30193, average=2657.075),
#  BarData(date=datetime.date(2017, 12, 12), open=2662.5, high=2670.25, low=2660.5, close=2665.125, volume=225937, barCount=30698, average=2665.95),
#  BarData(date=datetime.date(2017, 12, 13), open=2667.75, high=2672.5, low=2663.5, close=2666.375, volume=191174, barCount=27016, average=2668.875),
# ...

# %%
df = util.df(bars)

# %%
df.head()
# Out:
#                  date     open     high      low   close  volume  barCount  \
# 0 2017-12-06 15:30:00  2625.75  2631.25  2625.50  2629.5  143545     15318
# 1 2017-12-06 16:00:00  2629.50  2633.25  2624.00  2633.0  179189     21037
# 2 2017-12-06 17:00:00  2633.00  2633.75  2628.25  2629.5  103526     11557
# 3 2017-12-06 18:00:00  2629.50  2630.00  2626.00  2629.0   73277      8655
# 4 2017-12-06 19:00:00  2629.00  2632.25  2627.75  2632.0   56240      6126
#
#     average
# 0  2628.375
# 1  2629.025
# 2  2631.100
# 3  2627.975
# 4  2630.125

# %%
contract_b = Contract(conId=270516653)
contract_b
# Out:
# Contract(conId=270516653)

# %%
ib.qualifyContracts(contract_b)
# Out:
# [Contract(secType='FUT', conId=270516653, symbol='EOE', lastTradeDateOrContractMonth='20180316', multiplier='200', exchange='FTA', currency='EUR', localSymbol='FTIH8', tradingClass='FTI')]

# %%
bars = ib.reqHistoricalData(
        contract_b,
        '', 
        durationStr='60 D',
        barSizeSetting='1 day',
        whatToShow='TRADES',
        useRTH=True,
        formatDate=1)
bars
# Out:
# [BarData(date=datetime.date(2017, 12, 8), open=546.6, high=546.6, low=545.15, close=546.15, volume=6, barCount=4, average=545.5675),
#  BarData(date=datetime.date(2017, 12, 11), open=545.75, high=548.7, low=545.75, close=548.7, volume=3, barCount=3, average=546.8675),
#  BarData(date=datetime.date(2017, 12, 12), open=549.45, high=549.45, low=549.45, close=549.45, volume=5, barCount=3, average=549.45),
#  BarData(date=datetime.date(2017, 12, 13), open=550.05, high=550.05, low=548.1, close=548.1, volume=32, barCount=16, average=549.32),
#  BarData(date=datetime.date(2017, 12, 14), open=546.3, high=546.3, low=546.3, close=546.3, volume=1, barCount=1, average=546.3),
#  BarData(date=datetime.date(2017, 12, 15), open=546.0, high=546.0, low=545.0, close=545.0, volume=6, barCount=2, average=545.1675),
#  BarData(date=datetime.date(2017, 12, 19), open=552.7, high=552.7, low=550.2, close=550.25, volume=7, barCount=7, average=550.5775),
# ...

# %%
contract_d = Contract(conId=226638493, includeExpired=True)
ib.qualifyContracts(contract_d)
# Out:
# [Contract(secType='FUT', conId=226638493, symbol='EOE', lastTradeDateOrContractMonth='20170317', multiplier='200', exchange='FTA', currency='EUR', localSymbol='FTIH7', tradingClass='FTI')]

# %%
bars = ib.reqHistoricalData(
        contract_d,
        '20170317 00:00:00', 
        durationStr='60 D',
        barSizeSetting='1 day',
        whatToShow='TRADES',
        useRTH=True,
        formatDate=1)
bars
# Out:
# [BarData(date=datetime.date(2016, 12, 22), open=480.35, high=480.8, low=480.35, close=480.5, volume=5, barCount=3, average=480.71),
#  BarData(date=datetime.date(2016, 12, 23), open=480.5, high=480.9, low=480.5, close=480.85, volume=2, barCount=2, average=480.7),
#  BarData(date=datetime.date(2016, 12, 30), open=479.0, high=481.5, low=479.0, close=481.1, volume=21, barCount=4, average=479.12),
#  BarData(date=datetime.date(2017, 1, 3), open=486.35, high=486.35, low=485.9, close=485.8, volume=43, barCount=29, average=486.3325),
#  BarData(date=datetime.date(2017, 1, 4), open=485.1, high=485.35, low=485.1, close=485.45, volume=15, barCount=9, average=485.2575),
#  BarData(date=datetime.date(2017, 1, 5), open=486.1, high=486.15, low=484.65, close=484.85, volume=26, barCount=19, average=485.82),
#  BarData(date=datetime.date(2017, 1, 6), open=483.75, high=483.75, low=483.75, close=484.85, volume=2, barCount=1, average=483.75),
# ...
